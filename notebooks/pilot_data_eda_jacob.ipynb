# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import altair as alt

# %%
df = pd.read_csv("./data/pilot/pilot_data.csv",header=0)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2021-03-25 12:05:52
# 3                                2021-03-25 12:08:28
# 4                                2021-03-25 12:17:23
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2021-03-25 12:13:09             IP Address
# 3                                2021-03-25 12:23:58             IP Address
# 4                                2021-03-25 12:25:42             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
columns = [i for i in df.columns]
question_text = [i for i in df.loc[0]]
question_num_and_text = dict(zip(columns,question_text))
question_num_and_text
# Out:
# {'StartDate': 'Start Date',
#  'EndDate': 'End Date',
#  'Status': 'Response Type',
#  'IPAddress': 'IP Address',
#  'Progress': 'Progress',
#  'Duration (in seconds)': 'Duration (in seconds)',
#  'Finished': 'Finished',
#  'RecordedDate': 'Recorded Date',
#  'ResponseId': 'Response ID',
#  'RecipientLastName': 'Recipient Last Name',
#  'RecipientFirstName': 'Recipient First Name',
#  'RecipientEmail': 'Recipient Email',
#  'ExternalReference': 'External Data Reference',
#  'LocationLatitude': 'Location Latitude',
#  'LocationLongitude': 'Location Longitude',
#  'DistributionChannel': 'Distribution Channel',
#  'UserLanguage': 'User Language',
#  'Q_RecaptchaScore': 'Q_RecaptchaScore',
#  'Q35': 'The main rhetorical effect of the series of three phrases in the first paragraph (“the diminution, the subversion, the destruction”) is to',
#  'Q36': 'As used in Line 5  the word “channeled” most nearly means',
# ...

# %%
# Out:
# {'StartDate': 'Start Date',
#  'EndDate': 'End Date',
#  'Status': 'Response Type',
#  'IPAddress': 'IP Address',
#  'Progress': 'Progress',
#  'Duration (in seconds)': 'Duration (in seconds)',
#  'Finished': 'Finished',
#  'RecordedDate': 'Recorded Date',
#  'ResponseId': 'Response ID',
#  'RecipientLastName': 'Recipient Last Name',
#  'RecipientFirstName': 'Recipient First Name',
#  'RecipientEmail': 'Recipient Email',
#  'ExternalReference': 'External Data Reference',
#  'LocationLatitude': 'Location Latitude',
#  'LocationLongitude': 'Location Longitude',
#  'DistributionChannel': 'Distribution Channel',
#  'UserLanguage': 'User Language',
#  'Q_RecaptchaScore': 'Q_RecaptchaScore',
#  'Q35': 'The main rhetorical effect of the series of three phrases in the first paragraph (“the diminution, the subversion, the destruction”) is to',
#  'Q36': 'As used in Line 5  the word “channeled” most nearly means',
# ...

# %%
df['Q199'].unique
# Out:
# <bound method Series.unique of 0     What Color Background did you have in your que...
# 1                            {"ImportId":"QID225_TEXT"}
# 2                                                 black
# 3     White? I don't remember, nor do I really under...
# 4                                                 green
# 5                                                 white
# 6                                                 block
# 7                                                yellow
# 8                                                 black
# 9     asked a question related to Color Perception ....
# 10                                                black
# 11                                                Black
# 12                                                white
# 13                                                   NO
# 14                                                white
# 15                                                black
# ...

# %% [markdown]
# ## Things to change:
# Note: Question 199 should be changed to be multiple choice and more descriptive (include text color or contrast)

# %% [markdown]
# Also, we need to 1. make all questions mandatory 2. include a few questions to test whether they are actually doing the survey or are just clicking random stuff
#
#
#
#
#
# 12:47
# the second one can be done by asking some simple questions that won't really take any time twice during the survey at different points in a slightly different way to see if the answers are the same. If they are different, then they didn't really do the survey

# %%
df
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/De...
# 2                                 2021-03-25 12:05:52
# 3                                 2021-03-25 12:08:28
# 4                                 2021-03-25 12:17:23
# 5                                 2021-03-25 12:19:32
# 6                                 2021-03-25 12:33:09
# 7                                 2021-03-25 12:28:02
# 8                                 2021-03-25 12:39:03
# 9                                 2021-03-25 12:45:03
# 10                                2021-03-25 12:43:57
# 11                                2021-03-25 12:47:40
# 12                                2021-03-25 12:35:58
# 13                                2021-03-25 12:47:27
# 14                                2021-03-25 12:52:06
# 15                                2021-03-25 13:05:12
# ...
